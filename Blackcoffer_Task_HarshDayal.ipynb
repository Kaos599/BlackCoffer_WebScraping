# %%
# !pip install nltk textstat
import os
import pandas as pd
import re
from bs4 import BeautifulSoup
import requests
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from textstat import textstat
import nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: textstat in /usr/local/lib/python3.10/dist-packages (0.7.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat) (0.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from textstat) (75.1.0)

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords', quiet=True)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
INPUT_FILE = '/content/Input.xlsx'
OUTPUT_DIR = '/content/Articles'
OUTPUT_FILE = '/content/Output_Data_MAIN.xlsx'
STOPWORDS_DIR = '/content/Stopwords'
MASTER_DICT_DIR = '/content/MasterDictionary'

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
def load_dictionary(file_path):
    try:
        with open(file_path, 'r', encoding='latin-1') as f:
            words = {line.strip() for line in f}
            return words

    except FileNotFoundError:
        print(f"Error: {file_path} not found. Returning an empty set.")
        return set()

# %%
stop_words = set(stopwords.words('english'))
try:
  with open(os.path.join(STOPWORDS_DIR, 'StopWords_Auditor.txt'), 'r', encoding='latin-1') as f:
      stop_words.update(line.strip() for line in f)
except FileNotFoundError:
    print("StopWords_Auditor.txt not found, using default stopwords.")


positive_words = load_dictionary(os.path.join(MASTER_DICT_DIR, 'positive-words.txt'))
negative_words = load_dictionary(os.path.join(MASTER_DICT_DIR, 'negative-words.txt'))

print(f"Positive words loaded: {len(positive_words)}")
print(f"Negative words loaded: {len(negative_words)}")


if positive_words: print(f"Sample positive words: {list(positive_words)[:5]}")
if negative_words: print(f"Sample negative words: {list(negative_words)[:5]}")
# Out:
# Positive words loaded: 2006
# Negative words loaded: 4783
# Sample positive words: ['glorify', 'unity', 'sincerely', 'clearly', 'fearlessly']
# Sample negative words: ['irksomely', 'satirical', 'hurted', 'impractical', 'checkered']

# %%
def count_syllables(word):
    vowels = 'aeiouy'
    word = word.lower().strip()
    count = 0
    if word[0] in vowels:
        count += 1
    for index in range(1, len(word)):
        if word[index] in vowels and word[index - 1] not in vowels:
            count += 1
    if word.endswith('es') or word.endswith('ed'):
        count -= 1
    if count == 0:
        count += 1
    return count

# %%
def calculate_readability_metrics(text):
    sentences = sent_tokenize(text)
    words = word_tokenize(text)
    word_count = len(words)
    sentence_count = len(sentences)
    avg_sentence_length = word_count / sentence_count if sentence_count > 0 else 0

    complex_word_count = sum([1 for word in words if count_syllables(word) > 2])
    percentage_complex_words = (complex_word_count / word_count * 100) if word_count > 0 else 0

    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)

    avg_word_length = sum(len(word) for word in words) / word_count if word_count > 0 else 0

    return avg_sentence_length, percentage_complex_words, fog_index, complex_word_count, word_count, avg_word_length

# %%
def calculate_sentiment_scores(text):
    words = word_tokenize(text.lower())
    print(f"Words tokenized: {words[:10]}...")

    word_count = len(words)
    print(f"Word Count: {word_count}")

    positive_score = sum(1 for word in words if word in positive_words)
    negative_score = sum(1 for word in words if word in negative_words)


    print(f"Positive Score: {positive_score}")
    print(f"Negative Score: {negative_score}")

    polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
    subjectivity_score = (positive_score + negative_score) / (word_count + 0.000001)

    return positive_score, negative_score, polarity_score, subjectivity_score

# %%
def count_personal_pronouns(text):
    pronouns = re.findall(r'\b(I|we|my|ours|us)\b', text, flags=re.IGNORECASE)
    return len(pronouns)

# %%
def extract_article_content(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        title_element = soup.find('h1', class_=re.compile(r'entry-title|td-page-title'))
        title = title_element.text.strip() if title_element else "Title Not Found"

        content_div = soup.find('div', class_=re.compile(r'td-post-content|entry-content'))
        article_text = ""
        if content_div:
            for element in content_div.children:
                if element.name in ['p', 'h1', 'h2', 'h3', 'pre', 'ul', 'ol']:
                    article_text += element.get_text(strip=True) + "\n"
                elif element.name in ['img', 'figure', 'table', 'iframe']:
                    break

        if not article_text:
            article_text = "Content Not Found"

        return title, article_text

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        return "Error Fetching URL", "Error Fetching Content"
    except AttributeError as e:
        print(f"Error extracting data from {url}: {e}")
        return "Error Extracting Data", "Error Extracting Content"
    except Exception as e:
        print(f"An unexpected error occurred for {url}: {e}")
        return "Unexpected Error", "Error Extracting Content"

# %%
def save_article(file_path, title, body):
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(title + "\n\n" + body)



def extract_articles(input_file, output_dir):
    df = pd.read_excel(input_file)

    for index, row in df.iterrows():
        url_id = row['URL_ID']
        url = row['URL']

        print(f"Processing URL_ID: {url_id}, URL: {url}")
        title, body = extract_article_content(url)

        if title and body:
            save_article(os.path.join(output_dir, f"{url_id}.txt"), title, body)

# %%
def analyze_articles(input_dir, output_file):
    df_input = pd.read_excel(INPUT_FILE)
    results = []

    for index, row in df_input.iterrows():
        url_id = row['URL_ID']
        url = row['URL']
        file_path = os.path.join(input_dir, f"{url_id}.txt")

        if os.path.exists(file_path):
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    text = f.read()

                pos_score, neg_score, polarity, subjectivity = calculate_sentiment_scores(text)
                avg_sent_len, perc_complex, fog_index, complex_words, word_count, avg_word_len = calculate_readability_metrics(text)
                personal_pronouns = count_personal_pronouns(text)
                syllable_per_word = sum(count_syllables(word) for word in word_tokenize(text)) / word_count if word_count > 0 else 0


                results.append({
                    'URL_ID': url_id,
                    'URL': url,
                    'POSITIVE SCORE': pos_score,
                    'NEGATIVE SCORE': neg_score,
                    'POLARITY SCORE': polarity,
                    'SUBJECTIVITY SCORE': subjectivity,
                    'AVG SENTENCE LENGTH': avg_sent_len,
                    'PERCENTAGE OF COMPLEX WORDS': perc_complex,
                    'FOG INDEX': fog_index,
                    'COMPLEX WORD COUNT': complex_words,
                    'WORD COUNT': word_count,
                    'SYLLABLE PER WORD': avg_word_len,
                    'PERSONAL PRONOUNS': personal_pronouns,
                    'AVG WORD LENGTH': avg_word_len,
                })

                print(f"All scores added for URL_ID: {url_id}")

            except Exception as e:
                print(f"Error analyzing file {file_path}: {e}")
        else:
             print(f"File not found for URL_ID: {url_id}")

    # Save to Excel
    df = pd.DataFrame(results)
    df.to_excel(output_file, index=False)

# %%
extract_articles(INPUT_FILE, OUTPUT_DIR)
analyze_articles(OUTPUT_DIR, OUTPUT_FILE)
print("Analysis complete and saved to Output_Data.xlsx")
# Out:
# Processing URL_ID: Netclan20241017, URL: https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# Processing URL_ID: Netclan20241018, URL: https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# Processing URL_ID: Netclan20241019, URL: https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# Processing URL_ID: Netclan20241020, URL: https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# Processing URL_ID: Netclan20241021, URL: https://insights.blackcoffer.com/development-of-ea-robot-for-automated-trading/
# Processing URL_ID: Netclan20241022, URL: https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# Processing URL_ID: Netclan20241023, URL: https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# Processing URL_ID: Netclan20241024, URL: https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# Processing URL_ID: Netclan20241025, URL: https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# Processing URL_ID: Netclan20241026, URL: https://insights.blackcoffer.com/transforming-and-managing-a-large-scale-sql-pedigree-database-to-neo4j-graph-db/
# Processing URL_ID: Netclan20241027, URL: https://insights.blackcoffer.com/enhancing-model-accuracy-from-58-to-over-90-strategies-for-improving-predictive-performance/
# Processing URL_ID: Netclan20241028, URL: https://insights.blackcoffer.com/securing-sensitive-financial-data-with-privacy-preserving-machine-learning-for-predictive-analytics/
# Processing URL_ID: Netclan20241029, URL: https://insights.blackcoffer.com/enhancing-data-collection-for-research-institutions-addressing-survey-fatigue-and-incorporating-verbal-communication-for-richer-insights/
# Processing URL_ID: Netclan20241030, URL: https://insights.blackcoffer.com/analyzing-the-impact-of-positive-emotions-and-pandemic-severity-on-mental-health-and-resilience-among-entrepreneurs-insights-and-predictive-modeling/
# Processing URL_ID: Netclan20241031, URL: https://insights.blackcoffer.com/dynamic-brand-centric-dashboard-for-automotive-dealerships-pdf-to-financial-insights-with-flask-react-architecture-and-aws-cloud-hosting/
# Processing URL_ID: Netclan20241032, URL: https://insights.blackcoffer.com/cloud-based-data-modeling-and-analysis-platform-with-drag-and-drop-interface-and-openai-api-integration-for-simulation-insights/
# Processing URL_ID: Netclan20241033, URL: https://insights.blackcoffer.com/voter-profile-analysis-and-search-application-for-targeted-campaign-engagement-using-government-voter-data/
# Processing URL_ID: Netclan20241034, URL: https://insights.blackcoffer.com/bert-based-classification-of-individuals-and-organizations-into-two-categories-using-natural-language-processing/
# Processing URL_ID: Netclan20241035, URL: https://insights.blackcoffer.com/comprehensive-analysis-of-solana-and-ethereum-contributors-using-github-api-with-comparative-study-of-1000-random-github-profiles/
# Processing URL_ID: Netclan20241036, URL: https://insights.blackcoffer.com/powerbi-rest-api-fetching-dataflow-and-refresh-schedules-with-semantic-models/
# Processing URL_ID: Netclan20241037, URL: https://insights.blackcoffer.com/automated-job-data-import-and-management-solution-for-enhanced-efficiency/
# Processing URL_ID: Netclan20241038, URL: https://insights.blackcoffer.com/data-analytics-and-optimization-solution-for-enhancing-renewable-energy-efficiency/
# Processing URL_ID: Netclan20241039, URL: https://insights.blackcoffer.com/time-series-analysis-and-trend-forecasting-solution-for-predicting-news-trends/
# Processing URL_ID: Netclan20241040, URL: https://insights.blackcoffer.com/advanced-data-visualization-solutions-for-monitoring-key-business-metrics-with-integrated-interactive-dashboards/
# Processing URL_ID: Netclan20241041, URL: https://insights.blackcoffer.com/advanced-patient-data-analysis-solution-for-trend-identification-and-improved-healthcare-outcome/
# Processing URL_ID: Netclan20241042, URL: https://insights.blackcoffer.com/anomaly-detection-and-analysis-for-enhanced-data-integrity-and-user-experience-on-bright-datas-website/
# Processing URL_ID: Netclan20241043, URL: https://insights.blackcoffer.com/building-custom-tflite-models-and-benchmarking-on-voxl2-chips/
# Processing URL_ID: Netclan20241044, URL: https://insights.blackcoffer.com/sports-prediction-model-for-multiple-sports-leagues/
# Processing URL_ID: Netclan20241045, URL: https://insights.blackcoffer.com/efficient-coach-allocation-system-for-sports-coaching-organization/
# Processing URL_ID: Netclan20241046, URL: https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function-2/
# Processing URL_ID: Netclan20241047, URL: https://insights.blackcoffer.com/ai-driven-backend-for-audio-to-text-conversion-and-analytical-assessment-in-pharmaceutical-practice/
# Processing URL_ID: Netclan20241048, URL: https://insights.blackcoffer.com/cloud-based-web-application-for-financial-data-processing-and-visualization-of-sp-500-metrics/
# Processing URL_ID: Netclan20241049, URL: https://insights.blackcoffer.com/department-wise-kpi-tracking-dashboard-with-technician-performance-analysis-for-atoz-dependable-service/
# Processing URL_ID: Netclan20241050, URL: https://insights.blackcoffer.com/steps-to-convert-a-node-js-api-to-python-for-aws-lambda-deployment/
# Processing URL_ID: Netclan20241051, URL: https://insights.blackcoffer.com/building-an-analytics-dashboard-with-a-pdf-parsing-pipeline-for-data-extraction/
# Processing URL_ID: Netclan20241052, URL: https://insights.blackcoffer.com/building-a-real-time-log-file-visualization-dashboard-in-kibana/
# Processing URL_ID: Netclan20241053, URL: https://insights.blackcoffer.com/analyzing-the-impact-of-female-ceo-appointments-on-company-stock-prices/
# Processing URL_ID: Netclan20241054, URL: https://insights.blackcoffer.com/ai-chatbot-using-llm-langchain-llama/
# Processing URL_ID: Netclan20241055, URL: https://insights.blackcoffer.com/healthcare-ai-chatbot-using-llama-llm-langchain/
# Processing URL_ID: Netclan20241056, URL: https://insights.blackcoffer.com/ai-bot-audio-to-audio/
# Processing URL_ID: Netclan20241057, URL: https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/
# Processing URL_ID: Netclan20241058, URL: https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/
# Processing URL_ID: Netclan20241059, URL: https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/
# Processing URL_ID: Netclan20241060, URL: https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/
# Processing URL_ID: Netclan20241061, URL: https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/
# Processing URL_ID: Netclan20241062, URL: https://insights.blackcoffer.com/data-management-for-a-political-saas-application/
# Processing URL_ID: Netclan20241063, URL: https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/
# Processing URL_ID: Netclan20241064, URL: https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/
# Processing URL_ID: Netclan20241065, URL: https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/
# Processing URL_ID: Netclan20241066, URL: https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/
# Processing URL_ID: Netclan20241067, URL: https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/
# Processing URL_ID: Netclan20241068, URL: https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/
# Processing URL_ID: Netclan20241069, URL: https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/
# Processing URL_ID: Netclan20241070, URL: https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/
# Processing URL_ID: Netclan20241071, URL: https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/
# Processing URL_ID: Netclan20241072, URL: https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/
# Processing URL_ID: Netclan20241073, URL: https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/
# Processing URL_ID: Netclan20241074, URL: https://insights.blackcoffer.com/advanced-ai-for-trading-automation/
# Processing URL_ID: Netclan20241075, URL: https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/
# Processing URL_ID: Netclan20241076, URL: https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/
# Processing URL_ID: Netclan20241077, URL: https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/
# Processing URL_ID: Netclan20241078, URL: https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/
# Processing URL_ID: Netclan20241079, URL: https://insights.blackcoffer.com/handgun-detection-using-yolo/
# Processing URL_ID: Netclan20241080, URL: https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/
# Processing URL_ID: Netclan20241081, URL: https://insights.blackcoffer.com/car-detection-in-satellite-images/
# Processing URL_ID: Netclan20241082, URL: https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/
# Processing URL_ID: Netclan20241083, URL: https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/
# Processing URL_ID: Netclan20241084, URL: https://insights.blackcoffer.com/data-transformation/
# Processing URL_ID: Netclan20241085, URL: https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/
# Processing URL_ID: Netclan20241086, URL: https://insights.blackcoffer.com/kpi-dashboard-for-accountants/
# Processing URL_ID: Netclan20241087, URL: https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/
# Processing URL_ID: Netclan20241088, URL: https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/
# Processing URL_ID: Netclan20241089, URL: https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/
# Processing URL_ID: Netclan20241090, URL: https://insights.blackcoffer.com/trading-bot-for-forex/
# Processing URL_ID: Netclan20241091, URL: https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/
# Processing URL_ID: Netclan20241092, URL: https://insights.blackcoffer.com/medical-classification/
# Processing URL_ID: Netclan20241093, URL: https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/
# Processing URL_ID: Netclan20241094, URL: https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/
# Processing URL_ID: Netclan20241095, URL: https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/
# Processing URL_ID: Netclan20241096, URL: https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/
# Processing URL_ID: Netclan20241097, URL: https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/
# Processing URL_ID: Netclan20241098, URL: https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/
# Processing URL_ID: Netclan20241099, URL: https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/
# Processing URL_ID: Netclan20241100, URL: https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/
# Processing URL_ID: Netclan20241101, URL: https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/
# Processing URL_ID: Netclan20241102, URL: https://insights.blackcoffer.com/design-develop-an-app-in-retool-which-shows-the-progress-of-the-added-video/
# Processing URL_ID: Netclan20241103, URL: https://insights.blackcoffer.com/auvik-connectwise-integration-in-grafana/
# Processing URL_ID: Netclan20241104, URL: https://insights.blackcoffer.com/data-integration-and-big-data-performance-using-elk-stack/
# Processing URL_ID: Netclan20241105, URL: https://insights.blackcoffer.com/web-data-connector/
# Processing URL_ID: Netclan20241106, URL: https://insights.blackcoffer.com/an-app-for-updating-the-email-id-of-the-user-and-stripe-refund-tool-using-retool/
# Processing URL_ID: Netclan20241107, URL: https://insights.blackcoffer.com/an-ai-ml-based-web-application-that-detects-the-correctness-of-text-in-a-given-video/
# Processing URL_ID: Netclan20241108, URL: https://insights.blackcoffer.com/website-tracking-and-insights-using-google-analytics-google-tag-manager/
# Processing URL_ID: Netclan20241109, URL: https://insights.blackcoffer.com/dashboard-to-track-the-analytics-of-the-website-using-google-analytics-and-google-tag-manager/
# Processing URL_ID: Netclan20241110, URL: https://insights.blackcoffer.com/power-bi-dashboard-on-operations-transactions-and-marketing-embedding-the-dashboard-to-web-app/
# Processing URL_ID: Netclan20241111, URL: https://insights.blackcoffer.com/nft-data-automation-looksrare-and-etl-tool/
# Processing URL_ID: Netclan20241112, URL: https://insights.blackcoffer.com/optimize-the-data-scraper-program-to-easily-accommodate-large-files-and-solve-oom-errors/
# Processing URL_ID: Netclan20241113, URL: https://insights.blackcoffer.com/making-a-robust-way-to-sync-data-from-airtables-to-mongodb-using-python-etl-solution/
# Processing URL_ID: Netclan20241114, URL: https://insights.blackcoffer.com/incident-duration-prediction-infrastructure-and-real-estate/
# Processing URL_ID: Netclan20241115, URL: https://insights.blackcoffer.com/statistical-data-analysis-of-reinforced-concrete/
# Processing URL_ID: Netclan20241116, URL: https://insights.blackcoffer.com/database-normalization-segmentation-with-google-data-studio-dashboard-insights/
# Processing URL_ID: Netclan20241117, URL: https://insights.blackcoffer.com/power-bi-dashboard-to-drive-insights-from-complex-data-to-generate-business-insights/
# Processing URL_ID: Netclan20241118, URL: https://insights.blackcoffer.com/real-time-dashboard-to-monitor-infrastructure-activity-and-machines/
# Processing URL_ID: Netclan20241119, URL: https://insights.blackcoffer.com/electric-vehicles-ev-load-management-system-to-forecast-energy-demand/
# Processing URL_ID: Netclan20241120, URL: https://insights.blackcoffer.com/power-bi-data-driven-map-dashboard/
# Processing URL_ID: Netclan20241121, URL: https://insights.blackcoffer.com/google-local-service-ads-lsa-leads-dashboard/
# Processing URL_ID: Netclan20241122, URL: https://insights.blackcoffer.com/aws-lex-voice-and-chatbot/
# Processing URL_ID: Netclan20241123, URL: https://insights.blackcoffer.com/metabridges-api-decentraland-integration/
# Processing URL_ID: Netclan20241124, URL: https://insights.blackcoffer.com/microsoft-azure-chatbot-with-luis-language-understanding/
# Processing URL_ID: Netclan20241125, URL: https://insights.blackcoffer.com/impact-of-news-media-and-press-on-innovation-startups-and-investments/
# Processing URL_ID: Netclan20241126, URL: https://insights.blackcoffer.com/aws-quicksight-reporting-dashboard/
# Processing URL_ID: Netclan20241127, URL: https://insights.blackcoffer.com/google-data-studio-dashboard-for-marketing-ads-and-traction-data/
# Processing URL_ID: Netclan20241128, URL: https://insights.blackcoffer.com/gangala-in-e-commerce-big-data-etl-elt-solution-and-data-warehouse/
# Processing URL_ID: Netclan20241129, URL: https://insights.blackcoffer.com/big-data-solution-to-an-online-multivendor-marketplace-ecommerce-business/
# Processing URL_ID: Netclan20241130, URL: https://insights.blackcoffer.com/creating-a-custom-report-and-dashboard-using-the-data-got-from-atera-api/
# Processing URL_ID: Netclan20241131, URL: https://insights.blackcoffer.com/azure-data-lake-and-power-bi-dashboard/
# Processing URL_ID: Netclan20241132, URL: https://insights.blackcoffer.com/google-data-studio-pipeline-with-gcp-mysql/
# Processing URL_ID: Netclan20241133, URL: https://insights.blackcoffer.com/quickbooks-dashboard-to-find-patterns-in-finance-sales-and-forecasts/
# Processing URL_ID: Netclan20241134, URL: https://insights.blackcoffer.com/marketing-sales-and-financial-data-business-dashboard-wink-report/
# Processing URL_ID: Netclan20241135, URL: https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/
# Processing URL_ID: Netclan20241136, URL: https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/
# Processing URL_ID: Netclan20241137, URL: https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/
# Processing URL_ID: Netclan20241138, URL: https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/
# Processing URL_ID: Netclan20241139, URL: https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/
# Processing URL_ID: Netclan20241140, URL: https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/
# Processing URL_ID: Netclan20241141, URL: https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/
# Processing URL_ID: Netclan20241142, URL: https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/
# Processing URL_ID: Netclan20241143, URL: https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/
# Processing URL_ID: Netclan20241144, URL: https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/
# Processing URL_ID: Netclan20241145, URL: https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/
# Processing URL_ID: Netclan20241146, URL: https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/
# Processing URL_ID: Netclan20241147, URL: https://insights.blackcoffer.com/real-estate-data-warehouse/
# Processing URL_ID: Netclan20241148, URL: https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/
# Processing URL_ID: Netclan20241149, URL: https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/
# Processing URL_ID: Netclan20241150, URL: https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/
# Processing URL_ID: Netclan20241151, URL: https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/
# Processing URL_ID: Netclan20241152, URL: https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/
# Processing URL_ID: Netclan20241153, URL: https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/
# Processing URL_ID: Netclan20241154, URL: https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/
# Processing URL_ID: Netclan20241155, URL: https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/
# Processing URL_ID: Netclan20241156, URL: https://insights.blackcoffer.com/marbles-stimulation-using-python/
# Processing URL_ID: Netclan20241157, URL: https://insights.blackcoffer.com/stocktwits-data-structurization/
# Processing URL_ID: Netclan20241158, URL: https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/
# Processing URL_ID: Netclan20241159, URL: https://insights.blackcoffer.com/population-and-community-survey-of-america/
# Processing URL_ID: Netclan20241160, URL: https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/
# Processing URL_ID: Netclan20241161, URL: https://insights.blackcoffer.com/healthcare-data-analysis/
# Processing URL_ID: Netclan20241162, URL: https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/
# Processing URL_ID: Netclan20241163, URL: https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/
# Words tokenized: ['ai', 'and', 'ml-based', 'youtube', 'analytics', 'and', 'content', 'creation', 'tool', 'for']...
# Word Count: 149
# Positive Score: 3
# Negative Score: 1
# All scores added for URL_ID: Netclan20241017
# Words tokenized: ['enhancing', 'front-end', 'features', 'and', 'functionality', 'for', 'improved', 'user', 'experience', 'and']...
# Word Count: 919
# Positive Score: 20
# Negative Score: 9
# All scores added for URL_ID: Netclan20241018
# Words tokenized: ['roas', 'dashboard', 'for', 'campaign-wise', 'google', 'ads', 'budget', 'tracking', 'using', 'google']...
# Word Count: 306
# Positive Score: 11
# Negative Score: 5
# All scores added for URL_ID: Netclan20241019
# Words tokenized: ['efficient', 'processing', 'and', 'analysis', 'of', 'financial', 'data', 'from', 'pdf', 'files']...
# Word Count: 665
# Positive Score: 25
# Negative Score: 13
# All scores added for URL_ID: Netclan20241020
# Words tokenized: ['development', 'of', 'ea', 'robot', 'for', 'automated', 'trading', 'objective', ':', 'the']...
# Word Count: 728
# Positive Score: 16
# Negative Score: 2
# All scores added for URL_ID: Netclan20241021
# Words tokenized: ['ai', 'and', 'ml-based', 'youtube', 'analytics', 'and', 'content', 'creation', 'tool', 'for']...
# Word Count: 149
# Positive Score: 3
# Negative Score: 1
# All scores added for URL_ID: Netclan20241022
# Words tokenized: ['enhancing', 'front-end', 'features', 'and', 'functionality', 'for', 'improved', 'user', 'experience', 'and']...
# Word Count: 919
# Positive Score: 20
# Negative Score: 9
# All scores added for URL_ID: Netclan20241023
# Words tokenized: ['roas', 'dashboard', 'for', 'campaign-wise', 'google', 'ads', 'budget', 'tracking', 'using', 'google']...
# Word Count: 306
# Positive Score: 11
# Negative Score: 5
# All scores added for URL_ID: Netclan20241024
# Words tokenized: ['efficient', 'processing', 'and', 'analysis', 'of', 'financial', 'data', 'from', 'pdf', 'files']...
# Word Count: 665
# Positive Score: 25
# Negative Score: 13
# All scores added for URL_ID: Netclan20241025
# Words tokenized: ['transforming', 'and', 'managing', 'a', 'large-scale', 'sql', 'pedigree', 'database', 'to', 'neo4j']...
# Word Count: 430
# Positive Score: 5
# Negative Score: 4
# All scores added for URL_ID: Netclan20241026
# Words tokenized: ['enhancing', 'model', 'accuracy', 'from', '58', '%', 'to', 'over', '90', '%']...
# Word Count: 291
# Positive Score: 11
# Negative Score: 6
# All scores added for URL_ID: Netclan20241027
# Words tokenized: ['securing', 'sensitive', 'financial', 'data', 'with', 'privacy-preserving', 'machine', 'learning', 'for', 'predictive']...
# Word Count: 659
# Positive Score: 27
# Negative Score: 4
# All scores added for URL_ID: Netclan20241028
# Words tokenized: ['enhancing', 'data', 'collection', 'for', 'research', 'institutions', ':', 'addressing', 'survey', 'fatigue']...
# Word Count: 422
# Positive Score: 21
# Negative Score: 6
# All scores added for URL_ID: Netclan20241029
# Words tokenized: ['analyzing', 'the', 'impact', 'of', 'positive', 'emotions', 'and', 'pandemic', 'severity', 'on']...
# Word Count: 202
# Positive Score: 5
# Negative Score: 5
# All scores added for URL_ID: Netclan20241030
# Words tokenized: ['dynamic', ',', 'brand-centric', 'dashboard', 'for', 'automotive', 'dealerships', ':', 'pdf', 'to']...
# Word Count: 1369
# Positive Score: 65
# Negative Score: 26
# All scores added for URL_ID: Netclan20241031
# Words tokenized: ['cloud-based', 'data', 'modeling', 'and', 'analysis', 'platform', 'with', 'drag-and-drop', 'interface', 'and']...
# Word Count: 1021
# Positive Score: 26
# Negative Score: 16
# All scores added for URL_ID: Netclan20241032
# Words tokenized: ['voter', 'profile', 'analysis', 'and', 'search', 'application', 'for', 'targeted', 'campaign', 'engagement']...
# Word Count: 1553
# Positive Score: 76
# Negative Score: 14
# All scores added for URL_ID: Netclan20241033
# Words tokenized: ['bert-based', 'classification', 'of', 'individuals', 'and', 'organizations', 'into', 'two', 'categories', 'using']...
# Word Count: 105
# Positive Score: 3
# Negative Score: 1
# All scores added for URL_ID: Netclan20241034
# Words tokenized: ['comprehensive', 'analysis', 'of', 'solana', 'and', 'ethereum', 'contributors', 'using', 'github', 'api']...
# Word Count: 734
# Positive Score: 36
# Negative Score: 6
# All scores added for URL_ID: Netclan20241035
# Words tokenized: ['powerbi', 'rest', 'api', '–', 'fetching', 'dataflow', 'and', 'refresh', 'schedules', 'with']...
# Word Count: 589
# Positive Score: 35
# Negative Score: 12
# All scores added for URL_ID: Netclan20241036
# Words tokenized: ['automated', 'job', 'data', 'import', 'and', 'management', 'solution', 'for', 'enhanced', 'efficiency']...
# Word Count: 347
# Positive Score: 12
# Negative Score: 2
# All scores added for URL_ID: Netclan20241037
# Words tokenized: ['data', 'analytics', 'and', 'optimization', 'solution', 'for', 'enhancing', 'renewable', 'energy', 'efficiency']...
# Word Count: 356
# Positive Score: 11
# Negative Score: 3
# All scores added for URL_ID: Netclan20241038
# Words tokenized: ['time', 'series', 'analysis', 'and', 'trend', 'forecasting', 'solution', 'for', 'predicting', 'news']...
# Word Count: 344
# Positive Score: 11
# Negative Score: 3
# All scores added for URL_ID: Netclan20241039
# Words tokenized: ['advanced', 'data', 'visualization', 'solutions', 'for', 'monitoring', 'key', 'business', 'metrics', 'with']...
# Word Count: 337
# Positive Score: 17
# Negative Score: 2
# All scores added for URL_ID: Netclan20241040
# Words tokenized: ['advanced', 'patient', 'data', 'analysis', 'solution', 'for', 'trend', 'identification', 'and', 'improved']...
# Word Count: 342
# Positive Score: 20
# Negative Score: 3
# All scores added for URL_ID: Netclan20241041
# Words tokenized: ['anomaly', 'detection', 'and', 'analysis', 'for', 'enhanced', 'data', 'integrity', 'and', 'user']...
# Word Count: 392
# Positive Score: 15
# Negative Score: 10
# All scores added for URL_ID: Netclan20241042
# Words tokenized: ['building', 'custom', 'tflite', 'models', 'and', 'benchmarking', 'on', 'voxl2', 'chips', 'client']...
# Word Count: 792
# Positive Score: 16
# Negative Score: 3
# All scores added for URL_ID: Netclan20241043
# Words tokenized: ['sports', 'prediction', 'model', 'for', 'multiple', 'sports', 'leagues', 'client', 'background', 'client']...
# Word Count: 802
# Positive Score: 22
# Negative Score: 9
# All scores added for URL_ID: Netclan20241044
# Words tokenized: ['efficient', 'coach', 'allocation', 'system', 'for', 'sports', 'coaching', 'organization', 'client', 'background']...
# Word Count: 937
# Positive Score: 19
# Negative Score: 7
# All scores added for URL_ID: Netclan20241045
# Words tokenized: ['data', 'studio', 'dashboard', 'with', 'a', 'data', 'pipeline', 'tool', 'synced', 'with']...
# Word Count: 1000
# Positive Score: 27
# Negative Score: 12
# All scores added for URL_ID: Netclan20241046
# Words tokenized: ['ai-driven', 'backend', 'for', 'audio-to-text', 'conversion', 'and', 'analytical', 'assessment', 'in', 'pharmaceutical']...
# Word Count: 634
# Positive Score: 19
# Negative Score: 10
# All scores added for URL_ID: Netclan20241047
# Words tokenized: ['cloud-based', 'web', 'application', 'for', 'financial', 'data', 'processing', 'and', 'visualization', 'of']...
# Word Count: 882
# Positive Score: 58
# Negative Score: 16
# All scores added for URL_ID: Netclan20241048
# Words tokenized: ['department-wise', 'kpi', 'tracking', 'dashboard', 'with', 'technician', 'performance', 'analysis', 'for', 'atoz']...
# Word Count: 1252
# Positive Score: 31
# Negative Score: 9
# All scores added for URL_ID: Netclan20241049
# Words tokenized: ['steps', 'to', 'convert', 'a', 'node.js', 'api', 'to', 'python', 'for', 'aws']...
# Word Count: 598
# Positive Score: 21
# Negative Score: 9
# All scores added for URL_ID: Netclan20241050
# Words tokenized: ['building', 'an', 'analytics', 'dashboard', 'with', 'a', 'pdf', 'parsing', 'pipeline', 'for']...
# Word Count: 2109
# Positive Score: 50
# Negative Score: 31
# All scores added for URL_ID: Netclan20241051
# Words tokenized: ['building', 'a', 'real-time', 'log', 'file', 'visualization', 'dashboard', 'in', 'kibana', 'client']...
# Word Count: 1185
# Positive Score: 25
# Negative Score: 27
# All scores added for URL_ID: Netclan20241052
# Words tokenized: ['analyzing', 'the', 'impact', 'of', 'female', 'ceo', 'appointments', 'on', 'company', 'stock']...
# Word Count: 1133
# Positive Score: 25
# Negative Score: 8
# All scores added for URL_ID: Netclan20241053
# Words tokenized: ['ai', 'chatbot', 'using', 'llm', ',', 'langchain', ',', 'llama', 'objective', 'the']...
# Word Count: 128
# Positive Score: 3
# Negative Score: 0
# All scores added for URL_ID: Netclan20241054
# Words tokenized: ['healthcare', 'ai', 'chatbot', 'using', 'llama', ',', 'llm', ',', 'langchain', 'client']...
# Word Count: 2009
# Positive Score: 82
# Negative Score: 11
# All scores added for URL_ID: Netclan20241055
# Words tokenized: ['ai', 'bot', 'audio', 'to', 'audio', 'table', 'of', 'contents', 'application', 'architectureinstallationrunning']...
# Word Count: 40
# Positive Score: 0
# Negative Score: 0
# All scores added for URL_ID: Netclan20241056
# Words tokenized: ['recommendation', 'engine', 'for', 'insurance', 'sector', 'to', 'expand', 'business', 'in', 'the']...
# Word Count: 636
# Positive Score: 11
# Negative Score: 6
# All scores added for URL_ID: Netclan20241057
# Words tokenized: ['data', 'from', 'crm', 'via', 'zapier', 'to', 'google', 'sheets', '(', 'dynamic']...
# Word Count: 364
# Positive Score: 12
# Negative Score: 1
# All scores added for URL_ID: Netclan20241058
# Words tokenized: ['data', 'warehouse', 'to', 'google', 'data', 'studio', '(', 'looker', ')', 'dashboard']...
# Word Count: 360
# Positive Score: 5
# Negative Score: 1
# All scores added for URL_ID: Netclan20241059
# Words tokenized: ['crm', ',', 'monday.com', 'via', 'zapier', 'to', 'power', 'bi', 'dashboard', 'client']...
# Word Count: 401
# Positive Score: 9
# Negative Score: 3
# All scores added for URL_ID: Netclan20241060
# Words tokenized: ['monday.com', 'to', 'kpi', 'dashboard', 'to', 'manage', ',', 'view', ',', 'and']...
# Word Count: 462
# Positive Score: 16
# Negative Score: 7
# All scores added for URL_ID: Netclan20241061
# Words tokenized: ['data', 'management', 'for', 'a', 'political', 'saas', 'application', 'client', 'background', 'client']...
# Word Count: 502
# Positive Score: 2
# Negative Score: 4
# All scores added for URL_ID: Netclan20241062
# Words tokenized: ['google', 'lsa', 'ads', '(', 'google', 'local', 'service', 'ads', ')', '–']...
# Word Count: 241
# Positive Score: 3
# Negative Score: 1
# All scores added for URL_ID: Netclan20241063
# Words tokenized: ['ad', 'networks', 'marketing', 'campaign', 'data', 'dashboard', 'in', 'looker', '(', 'google']...
# Word Count: 148
# Positive Score: 3
# Negative Score: 1
# All scores added for URL_ID: Netclan20241064
# Words tokenized: ['analytical', 'solution', 'for', 'a', 'tech', 'firm', 'client', 'background', 'client', ':']...
# Word Count: 305
# Positive Score: 11
# Negative Score: 8
# All scores added for URL_ID: Netclan20241065
# Words tokenized: ['ai', 'solution', 'for', 'a', 'technology', ',', 'information', 'and', 'internet', 'firm']...
# Word Count: 275
# Positive Score: 6
# Negative Score: 2
# All scores added for URL_ID: Netclan20241066
# Words tokenized: ['ai', 'and', 'nlp-based', 'solutions', 'to', 'automate', 'data', 'discovery', 'for', 'venture']...
# Word Count: 346
# Positive Score: 3
# Negative Score: 2
# All scores added for URL_ID: Netclan20241067
# Words tokenized: ['an', 'etl', 'solution', 'for', 'an', 'internet', 'publishing', 'firm', 'client', 'background']...
# Word Count: 567
# Positive Score: 12
# Negative Score: 4
# All scores added for URL_ID: Netclan20241068
# Words tokenized: ['ai-based', 'algorithmic', 'trading', 'bot', 'for', 'forex', 'client', 'background', 'client', ':']...
# Word Count: 659
# Positive Score: 12
# Negative Score: 13
# All scores added for URL_ID: Netclan20241069
# Words tokenized: ['equity', 'waterfalls', 'model-based', 'saas', 'application', 'for', 'real', 'estate', 'sector', 'client']...
# Word Count: 407
# Positive Score: 1
# Negative Score: 4
# All scores added for URL_ID: Netclan20241070
# Words tokenized: ['ai', 'solutions', 'for', 'foreign', 'exchange', '–', 'an', 'automated', 'algo', 'trading']...
# Word Count: 433
# Positive Score: 6
# Negative Score: 4
# All scores added for URL_ID: Netclan20241071
# Words tokenized: ['ai', 'agent', 'development', 'and', 'deployment', 'in', 'jina', 'ai', 'client', 'background']...
# Word Count: 221
# Positive Score: 8
# Negative Score: 8
# All scores added for URL_ID: Netclan20241072
# Words tokenized: ['golden', 'record', '–', 'a', 'knowledge', 'graph', 'database', 'approach', 'to', 'unfold']...
# Word Count: 542
# Positive Score: 18
# Negative Score: 6
# All scores added for URL_ID: Netclan20241073
# Words tokenized: ['advanced', 'ai', 'for', 'trading', 'automation', 'client', 'background', 'client', ':', 'a']...
# Word Count: 451
# Positive Score: 13
# Negative Score: 5
# All scores added for URL_ID: Netclan20241074
# Words tokenized: ['create', 'a', 'knowledge', 'graph', 'to', 'provide', 'real-time', 'analytics', ',', 'recommendations']...
# Word Count: 195
# Positive Score: 3
# Negative Score: 6
# All scores added for URL_ID: Netclan20241075
# Words tokenized: ['advanced', 'ai', 'for', 'thermal', 'person', 'detection', 'client', 'background', 'client', ':']...
# Word Count: 148
# Positive Score: 6
# Negative Score: 2
# All scores added for URL_ID: Netclan20241076
# Words tokenized: ['advanced', 'ai', 'for', 'road', 'cam', 'threat', 'detection', 'client', 'background', 'client']...
# Word Count: 207
# Positive Score: 6
# Negative Score: 9
# All scores added for URL_ID: Netclan20241077
# Words tokenized: ['advanced', 'ai', 'for', 'pedestrian', 'crossing', 'safety', 'client', 'background', 'client', ':']...
# Word Count: 177
# Positive Score: 4
# Negative Score: 4
# All scores added for URL_ID: Netclan20241078
# Words tokenized: ['advanced', 'ai', 'for', 'handgun', 'detection', 'client', 'background', 'client', ':', 'a']...
# Word Count: 162
# Positive Score: 7
# Negative Score: 2
# All scores added for URL_ID: Netclan20241079
# Words tokenized: ['using', 'graph', 'technology', 'to', 'create', 'single', 'customer', 'view', '.', 'client']...
# Word Count: 197
# Positive Score: 2
# Negative Score: 9
# All scores added for URL_ID: Netclan20241080
# Words tokenized: ['car', 'detection', 'in', 'satellite', 'images', 'client', 'background', 'client', ':', 'a']...
# Word Count: 387
# Positive Score: 9
# Negative Score: 1
# All scores added for URL_ID: Netclan20241081
# Words tokenized: ['building', 'a', 'physics-informed', 'neural', 'network', 'for', 'circuit', 'evaluation', 'client', 'background']...
# Word Count: 445
# Positive Score: 13
# Negative Score: 4
# All scores added for URL_ID: Netclan20241082
# Words tokenized: ['connecting', 'mongodb', 'database', 'to', 'power', 'bi', 'dashboard', ':', 'dashboard', 'automation']...
# Word Count: 510
# Positive Score: 8
# Negative Score: 7
# All scores added for URL_ID: Netclan20241083
# Words tokenized: ['data', 'transformation', 'client', 'background', 'client', ':', 'a', 'leading', 'tech', 'firm']...
# Word Count: 562
# Positive Score: 22
# Negative Score: 13
# All scores added for URL_ID: Netclan20241084
# Words tokenized: ['e-commerce', 'store', 'analysis', '–', 'purchase', 'behavior', ',', 'ad', 'spend', ',']...
# Word Count: 436
# Positive Score: 7
# Negative Score: 1
# All scores added for URL_ID: Netclan20241085
# Words tokenized: ['kpi', 'dashboard', 'for', 'accountants', 'client', 'background', 'client', ':', 'a', 'leading']...
# Word Count: 354
# Positive Score: 11
# Negative Score: 0
# All scores added for URL_ID: Netclan20241086
# Words tokenized: ['return', 'on', 'advertising', 'spend', 'dashboard', ':', 'marketing', 'automation', 'and', 'analytics']...
# Word Count: 882
# Positive Score: 26
# Negative Score: 6
# All scores added for URL_ID: Netclan20241087
# Words tokenized: ['ranking', 'customer', 'behaviours', 'for', 'business', 'strategy', 'client', 'background', 'client', ':']...
# Word Count: 344
# Positive Score: 6
# Negative Score: 6
# All scores added for URL_ID: Netclan20241088
# Words tokenized: ['algorithmic', 'trading', 'for', 'multiple', 'commodities', 'markets', ',', 'like', 'forex', ',']...
# Word Count: 191
# Positive Score: 9
# Negative Score: 1
# All scores added for URL_ID: Netclan20241089
# Words tokenized: ['trading', 'bot', 'for', 'forex', 'client', 'background', 'client', ':', 'a', 'leading']...
# Word Count: 127
# Positive Score: 2
# Negative Score: 1
# All scores added for URL_ID: Netclan20241090
# Words tokenized: ['python', 'model', 'for', 'the', 'analysis', 'of', 'sector-specific', 'stock', 'etfs', 'for']...
# Word Count: 354
# Positive Score: 8
# Negative Score: 3
# All scores added for URL_ID: Netclan20241091
# Words tokenized: ['medical', 'classification', 'client', 'background', 'client', ':', 'a', 'leading', 'tech', 'firm']...
# Word Count: 435
# Positive Score: 12
# Negative Score: 4
# All scores added for URL_ID: Netclan20241092
# Words tokenized: ['design', '&', 'develop', 'bert', 'question', 'answering', 'model', 'explanations', 'with', 'visualization']...
# Word Count: 377
# Positive Score: 7
# Negative Score: 2
# All scores added for URL_ID: Netclan20241093
# Words tokenized: ['design', 'and', 'develop', 'solution', 'to', 'anomaly', 'detection', 'classification', 'problems', 'client']...
# Word Count: 314
# Positive Score: 9
# Negative Score: 16
# All scores added for URL_ID: Netclan20241094
# Words tokenized: ['an', 'etl', 'solution', 'for', 'currency', 'data', 'to', 'google', 'big', 'query']...
# Word Count: 431
# Positive Score: 2
# Negative Score: 18
# All scores added for URL_ID: Netclan20241095
# Words tokenized: ['etl', 'and', 'mlops', 'infrastructure', 'for', 'blockchain', 'analytics', 'client', 'background', 'client']...
# Word Count: 541
# Positive Score: 5
# Negative Score: 3
# All scores added for URL_ID: Netclan20241096
# Words tokenized: ['an', 'agent-based', 'model', 'of', 'a', 'virtual', 'power', 'plant', '(', 'vpp']...
# Word Count: 477
# Positive Score: 4
# Negative Score: 3
# All scores added for URL_ID: Netclan20241097
# Words tokenized: ['transform', 'api', 'into', 'sdk', 'library', 'and', 'widget', 'client', 'background', 'client']...
# Word Count: 250
# Positive Score: 11
# Negative Score: 1
# All scores added for URL_ID: Netclan20241098
# Words tokenized: ['integration', 'of', 'a', 'product', 'to', 'a', 'cloud-based', 'crm', 'platform', 'client']...
# Word Count: 343
# Positive Score: 8
# Negative Score: 7
# All scores added for URL_ID: Netclan20241099
# Words tokenized: ['a', 'web-based', 'dashboard', 'for', 'the', 'filtered', 'data', 'retrieval', 'of', 'land']...
# Word Count: 367
# Positive Score: 13
# Negative Score: 4
# All scores added for URL_ID: Netclan20241100
# Words tokenized: ['integration', 'of', 'video-conferencing', 'data', 'to', 'the', 'existing', 'web', 'app', 'client']...
# Word Count: 281
# Positive Score: 2
# Negative Score: 1
# All scores added for URL_ID: Netclan20241101
# Words tokenized: ['design', '&', 'develop', 'an', 'app', 'in', 'retool', 'which', 'shows', 'the']...
# Word Count: 248
# Positive Score: 6
# Negative Score: 0
# All scores added for URL_ID: Netclan20241102
# Words tokenized: ['auvik', ',', 'connectwise', 'integration', 'in', 'grafana', 'client', 'background', 'client', ':']...
# Word Count: 350
# Positive Score: 4
# Negative Score: 3
# All scores added for URL_ID: Netclan20241103
# Words tokenized: ['data', 'integration', 'and', 'big', 'data', 'performance', 'using', 'elasticsearch', 'client', 'background']...
# Word Count: 489
# Positive Score: 5
# Negative Score: 3
# All scores added for URL_ID: Netclan20241104
# Words tokenized: ['web', 'data', 'connector', 'client', 'background', 'client', ':', 'a', 'leading', 'marketing']...
# Word Count: 459
# Positive Score: 2
# Negative Score: 2
# All scores added for URL_ID: Netclan20241105
# Words tokenized: ['an', 'app', 'for', 'updating', 'the', 'email', 'id', 'of', 'the', 'user']...
# Word Count: 310
# Positive Score: 8
# Negative Score: 1
# All scores added for URL_ID: Netclan20241106
# Words tokenized: ['an', 'ai', 'ml-based', 'web', 'application', 'that', 'detects', 'the', 'correctness', 'of']...
# Word Count: 346
# Positive Score: 4
# Negative Score: 9
# All scores added for URL_ID: Netclan20241107
# Words tokenized: ['website', 'tracking', 'and', 'insights', 'using', 'google', 'analytics', ',', '&', 'google']...
# Word Count: 1101
# Positive Score: 31
# Negative Score: 2
# All scores added for URL_ID: Netclan20241108
# Words tokenized: ['dashboard', 'to', 'track', 'the', 'analytics', 'of', 'the', 'website', 'using', 'google']...
# Word Count: 1146
# Positive Score: 33
# Negative Score: 1
# All scores added for URL_ID: Netclan20241109
# Words tokenized: ['power', 'bi', 'dashboard', 'on', 'operations', ',', 'transactions', ',', 'and', 'marketing']...
# Word Count: 261
# Positive Score: 4
# Negative Score: 4
# All scores added for URL_ID: Netclan20241110
# Words tokenized: ['nft', 'data', 'automation', '(', 'looksrare', ')', ',', 'and', 'etl', 'tool']...
# Word Count: 418
# Positive Score: 10
# Negative Score: 4
# All scores added for URL_ID: Netclan20241111
# Words tokenized: ['optimize', 'the', 'data', 'scraper', 'program', 'to', 'easily', 'accommodate', 'large', 'files']...
# Word Count: 249
# Positive Score: 8
# Negative Score: 3
# All scores added for URL_ID: Netclan20241112
# Words tokenized: ['making', 'a', 'robust', 'way', 'to', 'sync', 'data', 'from', 'airtables', 'to']...
# Word Count: 178
# Positive Score: 2
# Negative Score: 1
# All scores added for URL_ID: Netclan20241113
# Words tokenized: ['incident', 'duration', 'prediction', '–', 'infrastructure', 'and', 'real', 'estate', 'client', 'background']...
# Word Count: 269
# Positive Score: 4
# Negative Score: 1
# All scores added for URL_ID: Netclan20241114
# Words tokenized: ['statistical', 'data', 'analysis', 'of', 'reinforced', 'concrete', 'client', 'background', 'client', ':']...
# Word Count: 572
# Positive Score: 8
# Negative Score: 3
# All scores added for URL_ID: Netclan20241115
# Words tokenized: ['database', 'normalization', '&', 'segmentation', 'with', 'google', 'data', 'studio', 'dashboard', 'insights']...
# Word Count: 274
# Positive Score: 6
# Negative Score: 0
# All scores added for URL_ID: Netclan20241116
# Words tokenized: ['power', 'bi', 'dashboard', 'to', 'drive', 'insights', 'from', 'complex', 'data', 'to']...
# Word Count: 392
# Positive Score: 6
# Negative Score: 3
# All scores added for URL_ID: Netclan20241117
# Words tokenized: ['real-time', 'dashboard', 'to', 'monitor', 'infrastructure', 'activity', 'and', 'machines', 'client', 'background']...
# Word Count: 278
# Positive Score: 1
# Negative Score: 3
# All scores added for URL_ID: Netclan20241118
# Words tokenized: ['electric', 'vehicles', '(', 'ev', ')', 'load', 'management', 'system', 'to', 'forecast']...
# Word Count: 508
# Positive Score: 9
# Negative Score: 6
# All scores added for URL_ID: Netclan20241119
# Words tokenized: ['power', 'bi', 'data-driven', 'map', 'dashboard', 'client', 'background', 'client', ':', 'a']...
# Word Count: 258
# Positive Score: 6
# Negative Score: 0
# All scores added for URL_ID: Netclan20241120
# Words tokenized: ['google', 'local', 'service', 'ads', '(', 'lsa', ')', 'leads', 'dashboard', 'client']...
# Word Count: 1030
# Positive Score: 49
# Negative Score: 7
# All scores added for URL_ID: Netclan20241121
# Words tokenized: ['aws', 'lex', 'voice', 'and', 'chatbot', 'client', 'background', 'client', ':', 'a']...
# Word Count: 696
# Positive Score: 22
# Negative Score: 1
# All scores added for URL_ID: Netclan20241122
# Words tokenized: ['metabridges', 'api', 'decentraland', 'integration', '–', 'ar', ',', 'vr', 'client', 'background']...
# Word Count: 362
# Positive Score: 2
# Negative Score: 3
# All scores added for URL_ID: Netclan20241123
# Words tokenized: ['microsoft', 'azure', 'chatbot', 'with', 'luis', '(', 'language', 'understanding', ')', 'client']...
# Word Count: 252
# Positive Score: 7
# Negative Score: 1
# All scores added for URL_ID: Netclan20241124
# Words tokenized: ['impact', 'of', 'news', ',', 'media', ',', 'and', 'press', 'on', 'innovation']...
# Word Count: 368
# Positive Score: 13
# Negative Score: 4
# All scores added for URL_ID: Netclan20241125
# Words tokenized: ['aws', 'quicksight', 'reporting', 'dashboard', 'client', 'background', 'overviewas', 'a', 'singapore', 'and']...
# Word Count: 470
# Positive Score: 11
# Negative Score: 3
# All scores added for URL_ID: Netclan20241126
# Words tokenized: ['google', 'data', 'studio', 'dashboard', 'for', 'marketing', ',', 'ads', 'and', 'traction']...
# Word Count: 574
# Positive Score: 13
# Negative Score: 4
# All scores added for URL_ID: Netclan20241127
# Words tokenized: ['gangala.in', ':', 'e-commerce', 'big', 'data', 'etl', '/', 'elt', 'solution', 'and']...
# Word Count: 410
# Positive Score: 9
# Negative Score: 3
# All scores added for URL_ID: Netclan20241128
# Words tokenized: ['big', 'data', 'solution', 'to', 'an', 'online', 'multivendor', 'marketplace', 'ecommerce', 'business']...
# Word Count: 632
# Positive Score: 27
# Negative Score: 4
# All scores added for URL_ID: Netclan20241129
# Words tokenized: ['creating', 'a', 'custom', 'report', 'and', 'dashboard', 'using', 'the', 'data', 'got']...
# Word Count: 213
# Positive Score: 1
# Negative Score: 3
# All scores added for URL_ID: Netclan20241130
# Words tokenized: ['azure', 'data', 'lake', 'and', 'power', 'bi', 'dashboard', 'client', 'background', 'overviewstone']...
# Word Count: 361
# Positive Score: 9
# Negative Score: 3
# All scores added for URL_ID: Netclan20241131
# Words tokenized: ['google', 'data', 'studio', 'pipeline', 'with', 'gcp/mysql', 'client', 'background', 'client', ':']...
# Word Count: 777
# Positive Score: 1
# Negative Score: 11
# All scores added for URL_ID: Netclan20241132
# Words tokenized: ['quickbooks', 'dashboard', 'to', 'find', 'patterns', 'in', 'finance', ',', 'sales', ',']...
# Word Count: 258
# Positive Score: 6
# Negative Score: 0
# All scores added for URL_ID: Netclan20241133
# Words tokenized: ['marketing', ',', 'sales', ',', 'and', 'financial', 'data', 'business', 'dashboard', '(']...
# Word Count: 776
# Positive Score: 18
# Negative Score: 3
# All scores added for URL_ID: Netclan20241134
# Words tokenized: ['react', 'native', 'apps', 'in', 'the', 'development', 'portfolio', 'here', 'are', 'the']...
# Word Count: 68
# Positive Score: 0
# Negative Score: 0
# All scores added for URL_ID: Netclan20241135
# Words tokenized: ['a', 'leading', 'law', 'firm', 'in', 'the', 'usa', ',', 'website', 'seo']...
# Word Count: 136
# Positive Score: 3
# Negative Score: 1
# All scores added for URL_ID: Netclan20241136
# Words tokenized: ['a', 'leading', 'hospitality', 'firm', 'in', 'the', 'usa', ',', 'website', 'seo']...
# Word Count: 143
# Positive Score: 8
# Negative Score: 0
# All scores added for URL_ID: Netclan20241137
# Words tokenized: ['a', 'leading', 'firm', 'in', 'the', 'usa', ',', 'website', 'seo', '&']...
# Word Count: 158
# Positive Score: 6
# Negative Score: 5
# All scores added for URL_ID: Netclan20241138
# Words tokenized: ['a', 'leading', 'musical', 'instrumental', ',', 'website', 'seo', '&', 'optimization', 'client']...
# Word Count: 103
# Positive Score: 4
# Negative Score: 3
# All scores added for URL_ID: Netclan20241139
# Words tokenized: ['a', 'leading', 'firm', 'in', 'the', 'usa', ',', 'seo', 'and', 'website']...
# Word Count: 99
# Positive Score: 3
# Negative Score: 1
# All scores added for URL_ID: Netclan20241140
# Words tokenized: ['immigration', 'datawarehouse', '&', 'ai-based', 'recommendations', 'client', 'background', 'client', ':', 'a']...
# Word Count: 404
# Positive Score: 11
# Negative Score: 2
# All scores added for URL_ID: Netclan20241141
# Words tokenized: ['lipsync', 'automation', 'for', 'celebrities', 'and', 'influencers', 'client', 'background', 'client', ':']...
# Word Count: 179
# Positive Score: 1
# Negative Score: 0
# All scores added for URL_ID: Netclan20241142
# Words tokenized: ['key', 'audit', 'matters', 'predictive', 'modeling', 'client', 'background', 'client', ':', 'a']...
# Word Count: 593
# Positive Score: 4
# Negative Score: 8
# All scores added for URL_ID: Netclan20241143
# Words tokenized: ['splitting', 'of', 'songs', 'into', 'its', 'vocals', 'and', 'instrumental', 'client', 'background']...
# Word Count: 279
# Positive Score: 10
# Negative Score: 3
# All scores added for URL_ID: Netclan20241144
# Words tokenized: ['ai', 'and', 'ml', 'technologies', 'to', 'evaluate', 'learning', 'assessments', 'client', 'background']...
# Word Count: 491
# Positive Score: 13
# Negative Score: 2
# All scores added for URL_ID: Netclan20241145
# Words tokenized: ['datawarehouse', ',', 'and', 'recommendations', 'engine', 'for', 'airbnb', 'client', 'background', 'client']...
# Word Count: 359
# Positive Score: 9
# Negative Score: 1
# All scores added for URL_ID: Netclan20241146
# Words tokenized: ['real', 'estate', 'data', 'warehouse', 'client', 'background', 'client', ':', 'a', 'leading']...
# Word Count: 120
# Positive Score: 1
# Negative Score: 0
# All scores added for URL_ID: Netclan20241147
# Words tokenized: ['traction', 'dashboards', 'of', 'marketing', 'campaigns', 'and', 'posts', 'client', 'background', 'client']...
# Word Count: 374
# Positive Score: 5
# Negative Score: 2
# All scores added for URL_ID: Netclan20241148
# Words tokenized: ['google', 'local', 'service', 'ads', '(', 'lsa', ')', 'data', 'warehouse', 'client']...
# Word Count: 265
# Positive Score: 4
# Negative Score: 1
# All scores added for URL_ID: Netclan20241149
# Words tokenized: ['google', 'local', 'service', 'ads', 'missed', 'calls', 'and', 'messages', 'automation', 'tool']...
# Word Count: 280
# Positive Score: 3
# Negative Score: 5
# All scores added for URL_ID: Netclan20241150
# Words tokenized: ['marketing', 'ads', 'leads', 'call', 'status', 'data', 'tool', 'to', 'bigquery', 'client']...
# Word Count: 231
# Positive Score: 5
# Negative Score: 1
# All scores added for URL_ID: Netclan20241151
# Words tokenized: ['marketing', 'analytics', 'to', 'automate', 'leads', 'call', 'status', 'and', 'reporting', 'client']...
# Word Count: 238
# Positive Score: 5
# Negative Score: 1
# All scores added for URL_ID: Netclan20241152
# Words tokenized: ['callrail', ',', 'analytics', '&', 'leads', 'report', 'alert', 'client', 'background', 'client']...
# Word Count: 272
# Positive Score: 3
# Negative Score: 1
# All scores added for URL_ID: Netclan20241153
# Words tokenized: ['marketing', 'tool', 'to', 'notify', 'leads', 'to', 'clients', 'over', 'email', 'and']...
# Word Count: 278
# Positive Score: 4
# Negative Score: 2
# All scores added for URL_ID: Netclan20241154
# Words tokenized: ['data', 'etl', ':', 'local', 'service', 'ads', 'leads', 'to', 'bigquery', 'client']...
# Word Count: 264
# Positive Score: 6
# Negative Score: 2
# All scores added for URL_ID: Netclan20241155
# Words tokenized: ['marbles', 'stimulation', 'using', 'python', 'client', 'background', 'client', ':', 'a', 'leading']...
# Word Count: 73
# Positive Score: 1
# Negative Score: 1
# All scores added for URL_ID: Netclan20241156
# Words tokenized: ['stocktwits', 'data', 'structurization', 'client', 'background', 'client', ':', 'a', 'leading', 'financial']...
# Word Count: 1000
# Positive Score: 15
# Negative Score: 11
# All scores added for URL_ID: Netclan20241157
# Words tokenized: ['sentimental', 'analysis', 'on', 'shareholder', 'letter', 'of', 'companies', 'client', 'background', 'client']...
# Word Count: 477
# Positive Score: 10
# Negative Score: 5
# All scores added for URL_ID: Netclan20241158
# Words tokenized: ['population', 'and', 'community', 'survey', 'of', 'america', 'client', 'background', 'client', ':']...
# Word Count: 778
# Positive Score: 13
# Negative Score: 3
# All scores added for URL_ID: Netclan20241159
# Words tokenized: ['google', 'lsa', 'api', 'data', 'automation', 'and', 'dashboarding', 'client', 'background', 'client']...
# Word Count: 1550
# Positive Score: 23
# Negative Score: 20
# All scores added for URL_ID: Netclan20241160
# Words tokenized: ['healthcare', 'data', 'analysis', 'client', 'background', 'client', ':', 'a', 'leading', 'healthcare']...
# Word Count: 437
# Positive Score: 10
# Negative Score: 12
# All scores added for URL_ID: Netclan20241161
# Words tokenized: ['budget', ',', 'sales', 'kpi', 'dashboard', 'using', 'power', 'bi', 'project', 'description']...
# Word Count: 153
# Positive Score: 0
# Negative Score: 0
# All scores added for URL_ID: Netclan20241162
# Words tokenized: ['amazon', 'buy', 'bot', ',', 'an', 'automation', 'ai', 'tool', 'to', 'auto-checkouts']...
# Word Count: 142
# Positive Score: 2
# Negative Score: 0
# All scores added for URL_ID: Netclan20241163
# Analysis complete and saved to Output_Data.xlsx
